# %%
import numpy as np

# sc_1 = np.loadtxt('scores_3d_1.txt')
# sc_2 = np.loadtxt('scores_3d_2.txt')
# sc_3 = np.loadtxt('scores_3d_3.txt')
# sc_4 = np.loadtxt('scores_3d_4.txt')
# sc_5 = np.loadtxt('scores_3d_5.txt')
# sc_6 = np.loadtxt('scores_3d_6.txt')
# sc_7 = np.loadtxt('scores_3d_7.txt')
# sc_8 = np.loadtxt('scores_3d_8.txt')
# sc_9 = np.loadtxt('scores_3d_9.txt')
# sc_10 = np.loadtxt('scores_3d_10.txt')
# sc_11 = np.loadtxt('scores_3d_11.txt')
# sc_12 = np.loadtxt('scores_3d_12.txt')
# sc_13 = np.loadtxt('scores_3d_13.txt')
# sc_14 = np.loadtxt('scores_3d_14.txt')
# sc_15 = np.loadtxt('scores_3d_15.txt')
# sc_16 = np.loadtxt('scores_3d_16.txt')
# sc_17 = np.loadtxt('scores_3d_17.txt')
# sc_18 = np.loadtxt('3d_scores_18.txt')
# sc_19 = np.loadtxt('3d_scores_19.txt')
# sc_20 = np.loadtxt('3d_scores_20.txt')
# sc_21 = np.loadtxt('3d_scores_21.txt')
# sc_22 = np.loadtxt('3d_scores_22.txt')
# sc_23 = np.loadtxt('3d_scores_23.txt')

# sc = np.concatenate([sc_1, sc_2, sc_3, sc_4, sc_5, sc_6, sc_7, sc_8, sc_9, 
#                      sc_10, sc_11,sc_12,sc_13,sc_14,sc_15, sc_16, sc_17, sc_18,sc_19,sc_20,sc_21, sc_22, sc_23])
#np.savetxt(X=sc, fname='score_3d_tot.txt')

sc_tot = np.loadtxt(fname='score_3d_tot.txt')

# %%
import matplotlib.pyplot as plt

w_l = 261
w_u = 266


# x = range(w_l,w_u, 1)
# plt.plot(x, sc[w_l:w_u])
plt.plot(sc_tot)
plt.grid(visible=True)
