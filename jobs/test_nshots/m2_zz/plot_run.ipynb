# %%
import numpy as np

sc_1 = np.loadtxt('scores_zz_1.txt')
sc_2 = np.loadtxt('scores_zz_2.txt')
sc_3 = np.loadtxt('scores_zz_3.txt')
sc_4 = np.loadtxt('scores_zz_4.txt')
sc_5 = np.loadtxt('scores_zz_5.txt')
sc_6 = np.loadtxt('scores_zz_6.txt')
sc_7 = np.loadtxt('scores_zz_7.txt')
sc_8 = np.loadtxt('scores_zz_8.txt')
sc_9 = np.loadtxt('scores_zz_9.txt')
sc_10 = np.loadtxt('scores_zz_10.txt')
sc_11 = np.loadtxt('scores_zz_11.txt')
sc_12 = np.loadtxt('scores_zz_12.txt')
sc_13 = np.loadtxt('scores_zz_13.txt')
sc_14 = np.loadtxt('scores_zz_14.txt')
sc_15 = np.loadtxt('scores_zz_15.txt')
sc_16 = np.loadtxt('scores_zz_16.txt')
sc_17 = np.loadtxt('scores_zz_17.txt')
sc_18 = np.loadtxt('scores_zz_18.txt')
sc_19 = np.loadtxt('scores_zz_19.txt')
sc_20 = np.loadtxt('scores_zz_20.txt')
sc = np.concatenate([sc_1, sc_2, sc_3, sc_4, sc_5, sc_6, sc_7, sc_8,sc_9,sc_10, 
                     sc_11, sc_12, sc_13,sc_14,sc_15, sc_16, sc_17, sc_18, sc_19, sc_20])

# %%
import matplotlib.pyplot as plt

w_l = 45
w_u = 52


x = range(w_l,w_u, 1)

#plt.plot(x, sc[w_l:w_u])
plt.plot(sc[0:1000])
plt.grid(visible=True)
#plt.plot(sc)

# %%
list(x)
# Out:
# [45, 46, 47, 48, 49, 50, 51]

# %%
list(sc[w_l:w_u])
# Out:
# [0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7]
