# %%
# import numpy as np

# sc_1 = np.loadtxt('scores_zz_1.txt')
# sc_2 = np.loadtxt('scores_zz_2.txt')
# sc_3 = np.loadtxt('scores_zz_3.txt')
# sc_4 = np.loadtxt('scores_zz_4.txt')
# sc_5 = np.loadtxt('scores_zz_5.txt')
# sc_6 = np.loadtxt('scores_zz_6.txt')
# sc_7 = np.loadtxt('scores_zz_7.txt')
# sc_8 = np.loadtxt('scores_zz_8.txt')
# sc_9 = np.loadtxt('scores_zz_9.txt')
# sc_10 = np.loadtxt('scores_zz_10.txt')
# sc_11 = np.loadtxt('scores_zz_11.txt')
# sc_12 = np.loadtxt('scores_zz_12.txt')
# sc_13 = np.loadtxt('scores_zz_13.txt')
# sc_14 = np.loadtxt('scores_zz_14.txt')
# sc_15 = np.loadtxt('scores_zz_15.txt')
# sc_16 = np.loadtxt('scores_zz_16.txt')
# sc_17 = np.loadtxt('scores_zz_17.txt')
# sc_18 = np.loadtxt('scores_zz_18.txt')
# sc_19 = np.loadtxt('scores_zz_19.txt')
# sc_20 = np.loadtxt('scores_zz_20.txt')
# sc_21 = np.loadtxt('scores_zz_21.txt')
# sc_22 = np.loadtxt('scores_zz_22.txt')
# sc_23 = np.loadtxt('scores_zz_23.txt')
# sc_24 = np.loadtxt('scores_zz_24.txt')
# sc_25 = np.loadtxt('scores_zz_25.txt')
# sc_26 = np.loadtxt('scores_zz_26.txt')
# sc_27 = np.loadtxt('scores_zz_27.txt')
# sc_28 = np.loadtxt('scores_zz_28.txt')
# sc_29 = np.loadtxt('scores_zz_29.txt')
# sc_30 = np.loadtxt('scores_zz_30.txt')
# sc_31 = np.loadtxt('scores_zz_31.txt')
# sc_32 = np.loadtxt('scores_zz_32.txt')
# sc_33 = np.loadtxt('scores_zz_33.txt')
# sc_34 = np.loadtxt('scores_zz_34.txt')
# sc_35 = np.loadtxt('scores_zz_35.txt')
# sc_36 = np.loadtxt('scores_zz_36.txt')
# sc_37 = np.loadtxt('scores_zz_37.txt')
# sc_38 = np.loadtxt('scores_zz_38.txt')
# sc_39 = np.loadtxt('scores_zz_39.txt')
# sc_40 = np.loadtxt('scores_zz_40.txt')

# sc = np.concatenate([sc_1, sc_2, sc_3, sc_4, sc_5, sc_6, sc_7, sc_8,sc_9,sc_10, 
#                      sc_11, sc_12, sc_13,sc_14,sc_15, sc_16, sc_17, sc_18, sc_19, sc_20,
#                      sc_21, sc_22, sc_23,sc_24,sc_25, sc_26, sc_27, sc_28, sc_29, sc_30,
#                      sc_31, sc_32, sc_33,sc_34,sc_35, sc_36, sc_37, sc_38, sc_39, sc_40])

# #np.savetxt(X=sc, fname='scores_zz_tot.txt')

# %%
import numpy as np

sc = np.loadtxt(fname='scores_zz_tot.txt')

# %%
import matplotlib.pyplot as plt

#w_l = 45
#w_u = 52
#x = range(w_l,w_u, 1)
#plt.plot(x, sc[w_l:w_u])
plt.plot(sc)


plt.grid(visible=True)
