# %%
import numpy as np

sc_1 = np.loadtxt('scores_1.txt')
sc_2 = np.loadtxt('scores_2.txt')
sc_3 = np.loadtxt('scores_3.txt')
sc_4 = np.loadtxt('scores_4.txt')
sc_5 = np.loadtxt('scores_5.txt')
sc_6 = np.loadtxt('scores_6.txt')
sc_7 = np.loadtxt('scores_7.txt')
sc_8 = np.loadtxt('scores_8.txt')
sc_9 = np.loadtxt('scores_9.txt')
sc_10 = np.loadtxt('scores_10.txt')
sc_11 = np.loadtxt('scores_11.txt')
sc_12 = np.loadtxt('scores_12.txt')
sc_13 = np.loadtxt('scores_13.txt')
sc_14 = np.loadtxt('scores_14.txt')
sc_15 = np.loadtxt('scores_15.txt')
sc = np.concatenate([sc_1, sc_2, sc_3, sc_4, sc_5, sc_6, sc_7, sc_8,sc_9,sc_10, sc_11, sc_12, sc_13,sc_14,sc_15])

# %%
import matplotlib.pyplot as plt

plt.plot(sc)
plt.grid(visible=True)
