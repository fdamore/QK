# %%
import numpy as np

nd_list = []

for i in range(1,51,1):
    nd_list.append(np.loadtxt(f'scores_{i}.txt'))   

sc =  np.concatenate(nd_list)   


# sc = np.concatenate([sc_1, sc_2, sc_3, sc_4, sc_5, sc_6, sc_7, sc_8, sc_9, 
#                      sc_10, sc_11,sc_12,sc_13,sc_14,sc_15, sc_16, sc_17, sc_18,sc_19,sc_20])

# %%
import matplotlib.pyplot as plt

w_l = 261
w_u = 266


# x = range(w_l,w_u, 1)
# plt.plot(x, sc[w_l:w_u])

plt.plot(sc)
plt.grid(visible=True)

# %%
gcv_nd_list = []

for i in range(1,5,1):
    gcv_nd_list.append(np.loadtxt(f'scores_gcv_{i}.txt'))   

gcv_sc =  np.concatenate(gcv_nd_list)

# %%
plt.plot(gcv_sc)
plt.grid(visible=True)
