# %%
#import numpy as np

# nd_list = []

# for i in range(1,51,1):
#     nd_list.append(np.loadtxt(f'scores_{i}.txt'))   

# sc =  np.concatenate(nd_list)   

#save data
#np.savetxt(X=sc, fname='scores_tot.txt')
# sc_51 =  np.loadtxt(f'scores_51.txt')
# sc_tot =  np.concatenate([sc, sc_51])

# %%
import numpy as np
sc = np.loadtxt(fname='scores_tot.txt')

# %%
import matplotlib.pyplot as plt

w_l = 261
w_u = 266


# x = range(w_l,w_u, 1)
# plt.plot(x, sc[w_l:w_u])

plt.plot(sc)
plt.grid(visible=True)

plt.xlabel('Number of Shots')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# gcv_nd_list = []

# for i in range(1,15,1):
#     gcv_nd_list.append(np.loadtxt(f'scores_gcv_{i}.txt'))   

# gcv_sc =  np.concatenate(gcv_nd_list)

# %%
#np.savetxt(X=gcv_sc, fname='scores_gcv_tot.txt')
gcv_sc = np.loadtxt(fname='scores_gcv_tot.txt')

# %%
plt.plot([_ for _ in range(1,len(gcv_sc)+1)], gcv_sc)
plt.grid(visible=True)

# %%
np.max(gcv_sc)
# Out:
# 0.8952912940717818
