# %%
# %load_ext autoreload
# %autoreload 2

# %%
#needed to import qke procedures
import sys
from pathlib import Path

main_dir = str(Path().resolve().parent)
sys.path.insert(1, main_dir)

# %% [markdown]
# Try classical SVM

# %%
#scikit learn and tools
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#load dataset with panda
#data are scaled outside the notebook
env = pd.read_csv('../data/env.sel3.scaled.csv')

# %%
#take a look of the dataset
env.describe()
# Out:
#         illuminance       blinds        lamps           rh           co2  \
# count  2.865000e+03  2865.000000  2865.000000  2865.000000  2.865000e+03
# mean  -3.571314e-16     0.801622     0.596464     0.473229 -5.952190e-16
# std    1.000000e+00     0.372305     0.489316     0.080185  1.000000e+00
# min   -1.016287e+00     0.000000     0.000000     0.243300 -1.222685e+00
# 25%   -8.575745e-01     1.000000     0.000000     0.433700 -8.492006e-01
# 50%   -6.989177e-02     1.000000     1.000000     0.491100 -3.252814e-01
# 75%    3.357060e-01     1.000000     1.000000     0.524100  7.569402e-01
# max    8.559349e+00     1.000000     1.000000     0.633300  3.583699e+00
#
#                temp    occupancy
# count  2.865000e+03  2865.000000
# mean  -7.142629e-16    -0.130192
# std    1.000000e+00     0.991662
# min   -1.774534e+00    -1.000000
# 25%   -8.538436e-01    -1.000000
# 50%   -1.940149e-01    -1.000000
# 75%    7.266751e-01     1.000000
# max    2.614091e+00     1.000000

# %%
#DEFINE design matrix
Y = env['occupancy']
#X = env[['illuminance', 'blinds','lamps','co', 'rh', 'co2', 'temp']]
X = env[['illuminance', 'blinds','lamps','rh', 'co2', 'temp']]

X.head()
# Out:
#    illuminance  blinds  lamps      rh       co2      temp
# 0    -0.992774     1.0    0.0  0.4069 -1.001777 -0.061027
# 1    -0.992774     1.0    0.0  0.4069 -0.892611 -0.061027
# 2    -0.992774     1.0    0.0  0.4069 -1.002203 -0.061027
# 3    -0.992774     1.0    0.0  0.4069 -0.867245 -0.061027
# 4    -0.992774     1.0    0.0  0.4069 -0.958793 -0.061027

# %%
Y.head()
# Out:
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: occupancy, dtype: int64

# %%
#split design matrix (25% of the design matrix used for test)
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=123)

# %%
#sanity check
print('TRAIN*****')
display(X_train.head())
display(X_train.describe())
print('TEST*****')
display(X_test.head())
display(X_test.describe())
# Out:
# TRAIN*****
#       illuminance  blinds  lamps      rh       co2      temp
# 2059    -1.016287    1.00    0.0  0.5320 -0.411241 -0.413958
# 91       0.271046    1.00    0.0  0.3782 -1.130711  1.693400
# 685     -0.587176    1.00    0.0  0.2714 -0.998338  1.652480
# 2438    -0.546028    1.00    0.0  0.5418 -1.138449 -1.595511
# 953     -1.010408    0.04    0.0  0.4667 -0.651917 -1.027752
#        illuminance       blinds        lamps           rh          co2  \
# count  2148.000000  2148.000000  2148.000000  2148.000000  2148.000000
# mean      0.000614     0.802182     0.593878     0.473322     0.000362
# std       1.020643     0.372034     0.489967     0.080160     0.999920
# min      -1.016287     0.000000     0.000000     0.243300    -1.219246
# 25%      -0.875209     1.000000     0.000000     0.433100    -0.847903
# 50%      -0.069892     1.000000     1.000000     0.492300    -0.363317
# 75%       0.323950     1.000000     1.000000     0.524100     0.756940
# max       8.559349     1.000000     1.000000     0.633300     3.583699
#
#               temp
# count  2148.000000
# mean     -0.004299
# std       0.995423
# min      -1.774534
# 25%      -0.853844
# 50%      -0.194015
# 75%       0.726675
# max       2.614091
# TEST*****
#       illuminance  blinds  lamps      rh       co2      temp
# 342     -1.016287    0.06    0.0  0.4710 -0.801916  0.905698
# 221      3.045570    1.00    1.0  0.3831 -0.694474  0.992653
# 2859    -0.969261    1.00    0.0  0.5009 -1.200340 -1.288614
# 1710    -0.981017    1.00    0.0  0.5289 -0.720258 -1.467638
# 762      0.347462    1.00    1.0  0.4978  1.082732 -0.981717
#        illuminance      blinds       lamps          rh         co2        temp
# count   717.000000  717.000000  717.000000  717.000000  717.000000  717.000000
# mean     -0.001838    0.799944    0.604212    0.472949   -0.001084    0.012880
# std       0.936118    0.373369    0.487620    0.080313    1.000937    1.014180
# min      -1.016287    0.000000    0.000000    0.243300   -1.222685   -1.774534
# 25%      -0.822305    1.000000    0.000000    0.433700   -0.867245   -0.853844
# 50%      -0.058135    1.000000    1.000000    0.487400   -0.297775   -0.147981
# 75%       0.353341    1.000000    1.000000    0.524100    0.756940    0.813629
# max       6.202179    1.000000    1.000000    0.633300    3.475396    2.614091

# %%
#WARNING: convert data to numpy. Quantum stuff (Qiskit) do not like PANDAS
X_train_np = X_train.to_numpy()
y_train_np = y_train.to_numpy()

X_test_np = X_test.to_numpy()
y_test_np = y_test.to_numpy()

# %%
#check the shape of test and training dataset
print(f'Training shape dataset {X_train_np.shape}')
print(f'Label for traing {y_train_np.shape}')

print(f'Test shape dataset {X_test_np.shape}')
print(f'Label for test {y_test_np.shape}')
# Out:
# Training shape dataset (2148, 6)
# Label for traing (2148,)
# Test shape dataset (717, 6)
# Label for test (717,)

# %%
#try SVM using RBF kernel
svm = SVC(kernel='rbf').fit(X_train_np, y_train_np);
#result...
predictions = svm.predict(X_test_np)
accuracy_score(predictions, y_test)
# Out:
# 0.8284518828451883

# %% [markdown]
# Try quantum Kernel Method

# %%
#Create a cotainer
from qke.CircuitContainer import CircuitContainer
from qke.Circuits import Circuits


c = CircuitContainer(qtemplate=Circuits.z_encoded, nwire=6, obs=['ZIIIII', 'ZIIZII','ZZZZZZ', 'IZIIII','ZZIIII','ZZIIZI'])
# Out:
# *** Create a Container ***
# *** Quantum template for feature map using 6 qubit ***
#      ┌───────────┐                         ┌───┐
# q_0: ┤ Rz(phi_0) ├──■──────────────────────┤ X ├
#      ├───────────┤┌─┴─┐                    └─┬─┘
# q_1: ┤ Rz(phi_1) ├┤ X ├──■───────────────────┼──
#      ├───────────┤└───┘┌─┴─┐                 │
# q_2: ┤ Rz(phi_2) ├─────┤ X ├──■──────────────┼──
#      ├───────────┤     └───┘┌─┴─┐            │
# q_3: ┤ Rz(phi_3) ├──────────┤ X ├──■─────────┼──
#      ├───────────┤          └───┘┌─┴─┐       │
# q_4: ┤ Rz(phi_4) ├───────────────┤ X ├──■────┼──
#      ├───────────┤               └───┘┌─┴─┐  │
# q_5: ┤ Rz(phi_5) ├────────────────────┤ X ├──■──
#      └───────────┘                    └───┘
# *** Required observables: ['ZIIIII', 'ZIIZII', 'ZZZZZZ', 'IZIIII', 'ZZIIII', 'ZZIIZI']
# *** Measure procedure: Aer
# *** CKernel function used: linear

# %%
#try SVM using linear kernel (dot product)
from qke.qkernel import kernel_matrix

svm_quantum = SVC(kernel=kernel_matrix).fit(X_train_np, y_train_np);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 #try SVM using linear kernel (dot product)
#       2 from qke.qkernel import kernel_matrix
# ----> 4 svm_quantum = SVC(kernel=kernel_matrix).fit(X_train_np, y_train_np);
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:310, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     306 if callable(self.kernel):
#     307     # you must store a reference to X to compute the kernel in predict
#     308     # TODO: add keyword copy to copy on demand
#     309     self.__Xfit = X
# --> 310     X = self._compute_kernel(X)
#     312     if X.shape[0] != X.shape[1]:
#     313         raise ValueError("X.shape[0] should be equal to X.shape[1]")
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:508, in BaseLibSVM._compute_kernel(self, X)
#     504 """Return the data transformed by a callable kernel"""
#     505 if callable(self.kernel):
#     506     # in the case of precomputed kernel given as a function, we
#     507     # have to compute explicitly the kernel matrix
# --> 508     kernel = self.kernel(X, self.__Xfit)
#     509     if sp.issparse(kernel):
#     510         kernel = kernel.toarray()
#
# File ~/git/QK/qke/qkernel.py:49, in kernel_matrix(A, B)
#      47 def kernel_matrix(A, B):
#      48     #Compute gram matrix
# ---> 49     return np.array([[qfKernel(a, b) for b in B] for a in A])
#
# File ~/git/QK/qke/qkernel.py:18, in qfKernel(x1, x2)
#      15 obs = circuit_container.obs
#      17 #define the key
# ---> 18 k_x1 = str(x1) #get_key(x1)
#      19 k_x2 = str(x2) #get_key(x2)
#      21 #check the k1 and get feature map
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/numpy/core/arrayprint.py:1612, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1606 if a.shape == ():
#    1607     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1608     # for which indexing with () returns a 0d instead of a scalar by using
#    1609     # ndarray's getindex. Also guard against recursive 0d object arrays.
#    1610     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
# -> 1612 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/numpy/core/arrayprint.py:736, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     733 if a.size == 0:
#     734     return "[]"
# --> 736 return _array2string(a, options, separator, prefix)
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/numpy/core/arrayprint.py:513, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     511 repr_running.add(key)
#     512 try:
# --> 513     return f(self, *args, **kwargs)
#     514 finally:
#     515     repr_running.discard(key)
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/numpy/core/arrayprint.py:546, in _array2string(a, options, separator, prefix)
#     543 # skip over array(
#     544 next_line_prefix += " "*len(prefix)
# --> 546 lst = _formatArray(a, format_function, options['linewidth'],
#     547                    next_line_prefix, separator, options['edgeitems'],
#     548                    summary_insert, options['legacy'])
#     549 return lst
#
# File ~/git/QK/.venv/lib/python3.12/site-packages/numpy/core/arrayprint.py:780, in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     776     line += suffix_length*' '
#     778     return s, line
# --> 780 def _formatArray(a, format_function, line_width, next_line_prefix,
#     781                  separator, edge_items, summary_insert, legacy):
#     782     """formatArray is designed for two modes of operation:
#     783
#     784     1. Full output
#    (...)
#     787
#     788     """
#     789     def recurser(index, hanging_indent, curr_width):
#
# KeyboardInterrupt:

# %%
q_predictions = svm_quantum.predict(X_test_np)
accuracy_score(q_predictions, y_test_np)
# Out:
# 0.796373779637378

# %%
#try embedding on single sample
from qke.qkernel import qfKernel

x1 = X_train_np[0]
x2 = X_train_np[1]
quantum_kernel = qfKernel(x1, x2)
classic_dot_product = x1.dot(x2)

print(f'Quantum kernel: {quantum_kernel}')
print(f'Classic dot product: {classic_dot_product}')

#check if different from classic
if quantum_kernel == classic_dot_product:
    print('Is the same that clasical')
else:
    print('Is not the same taht classical')

simmetric_kernel = qfKernel(x2,x1)
print(simmetric_kernel)

if simmetric_kernel == quantum_kernel:
    print('Is ismmetric')
# Out:
# Quantum kernel: 0.6804946853218848
# Classic dot product: 1.341463615504249
# Is not the same taht classical
# 0.6804946853218848
# Is ismmetric
