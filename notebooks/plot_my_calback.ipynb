# %%
# %load_ext autoreload
# %autoreload 2

# %%
#needed to import qke procedures
import sys
from pathlib import Path

main_dir = str(Path().resolve().parent)
sys.path.insert(1, main_dir)

# %%
#define the callback
from pqk.QKCallback import QKCallback

print(Path().absolute())

file_to_plot = '../qfm/callback/print_20241206163416.json'

QKCallback.plot_data_file(file=file_to_plot)
# Out:
# /home/francesco/git/QK/notebooks
